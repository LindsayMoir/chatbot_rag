# %% [markdown]
# # Chatbot Using Retrieval Augmented Generation (RAG)

# %% [markdown]
# I want an assistant that can tell me if the scientific information that I am receiving is current. ChatGPT3.5 is only trained to January 2022. So, anything past that, it will not have the information or ... it will lie:)

# %% [markdown]
# ## Import Libraries

# %%
from scipy.spatial.distance import cosine
import numpy as np
from openai import OpenAI # for calling the OpenAI API
import pandas as pd
import pprint
import re
import requests
import sys

# %% [markdown]
# ## Data Wrangling
#
# We will use Wikipedia as our source. Put the RAG text into a Pandas dataframe.

# %%
# I was originally going to do multiple topics, but decided to just do one
topics = ['2024 in science']
topics
# Out:
# ['2024 in science']

# %%
def get_wikipedia_content(topic):
    # Base URL of the Wikimedia API
    base_url = "https://en.wikipedia.org/w/api.php"
    
    # Parameters for the API request
    params = {
        "action": "query",
        "format": "json",
        "prop": "extracts",
        "titles": topic
    }
    
    # Send a GET request to the Wikimedia API
    response = requests.get(base_url, params=params)\
    
    # Parse the JSON response
    data = response.json()
    
    return data

# %%
# Example usage
topic = topics[0]
data = get_wikipedia_content(topic)

# Create a PrettyPrinter object with desired configurations
pp = pprint.PrettyPrinter(width=40, depth=2)

# Print the data
pp.pprint(data)
# Out:
# {'batchcomplete': '',
#  'query': {'pages': {...}},
#  'warnings': {'extracts': {...}}}

# %%
# Extracting the key from the nested JSON object. We just want the first hit.
# We will need this later.
pages = data['query']['pages']
page_key = list(pages.keys())[0]
page_key
# Out:
# '74041015'

# %%
def extract_events(html):
    events = {}
    current_date = None

    # Find all occurrences of dates in the format "digit space Month"
    date_pattern = r'\b(\d{1,2}\s(?:January|February|March|April|May|June|July|August|September|October|November|December))\b'
    dates = re.findall(date_pattern, html)
    
    # Define the pattern to match HTML tags
    html_tags_pattern = re.compile(r'<.*?>')

    for date in dates:
        if current_date is not None:
            current_event = []

        current_date = date

        # Find the text between two consecutive dates
        event_pattern = re.escape(date) + r'(.*?)' + re.escape(dates[dates.index(date) + 1] if dates.index(date) < len(dates) - 1 else '')
        event_text_match = re.search(event_pattern, html, re.DOTALL)
        
        # Where there are multiple events on a date split those into a list.
        if event_text_match:
            event_text = event_text_match.group(1)
            if event_text.startswith('\n<ul><li>'):
                event_text_list = event_text.split('</li>')
                cleaned_value = [remove_html_and_newlines(item) for item in event_text_list]
                cleaned_value = [value for value in cleaned_value if value != '']  
                event_text = cleaned_value
            else:
                event_text = [remove_html_and_newlines(event_text)]

            events[current_date] = event_text

    return events

# %%
def remove_html_and_newlines(text):
    
    # Remove HTML tags
    cleaned_text = re.sub(r'<.*?>', '', text)
    
    # Remove newline characters
    cleaned_text = cleaned_text.replace('\n', '')
    
    # Remove any extra whitespace
    cleaned_text = ' '.join(cleaned_text.split())
    
    return cleaned_text

# %%
# Put into events_dict
data = get_wikipedia_content(topics[0])

# We just want the extract
extract = data['query']['pages'][page_key]['extract']

# Create the dictionary
events_dict = extract_events(extract)

# %%
# Check and see what they look like.
events_dict['3 January']
# Out:
# ['– The first functional semiconductor made from graphene is created.']

# %%
# See what happens when there is more than one event on a date
print(len(events_dict['9 January']))
events_dict['9 January']
# Out:
# 5
# ['Scientists report studies which seem to support the hypothesis that life may have begun in a shallow lake rather than otherwise - perhaps somewhat like a "warm little pond" originally proposed by Charles Darwin.',
#  'A group of scientists from around the globe have charted paradigm shifting restorative pathways to mitigate the worst effects of climate change and biodiversity loss with a strong emphasis on environmental sustainability, human wellbeing and reducing social and economic inequality.',
#  'Researchers have discovered a new phase of matter, named a "light-matter hybrid", which may reshape understanding of how light interacts with matter.',
#  "A study of proteins in cerebrospinal fluid indicates there are five subtypes of Alzheimer's disease, suggesting it to be likely that subtype-specific treatments are required.",
#  'A study finds seaweed farming could be set up as a resilient food solution within roughly a year in abrupt sunlight reduction scenarios such as after a nuclear war or a large volcano eruption.']

# %%
data
# Out:
# {'batchcomplete': '',
#  'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Special:MyLanguage/Extension:TextExtracts#Caveats.'}},
#  'query': {'pages': {'74041015': {'pageid': 74041015,
#     'ns': 0,
#     'title': '2024 in science',
#     'extract': '<p class="mw-empty-elt">\n</p><p>The following scientific events occurred or are scheduled to occur in 2024.\n</p>\n\n\n<h2><span id="Events">Events</span></h2>\n<h3><span id="January">January</span></h3>\n<ul><li>2 January – The Japan Meteorological Agency (JMA) publishes its JRA-55 dataset, confirming 2023 as the warmest year on record globally, at 1.43\xa0°C (2.57\xa0°F) above the 1850–1900 baseline. This is 0.14\xa0°C (0.25\xa0°F) above the previous record set in 2016.</li>\n<li>3 January – The first functional semiconductor made from graphene is created.</li>\n<li>4 January – A review indicates digital rectal examination is an outdated routine medical practice, with lower cancer detection rate compared to prostate-specific antigen testing.</li>\n<li>5 January\n<ul><li>Scientists report that newborn galaxies in the very early universe were "banana"-shaped, much to the surprise of researchers.</li>\n<li>An analysis of sugar-sweetened beverage (SSB) taxes concludes scaling them could yield substantial public health benefits.</li></ul></li>\n<li>9 January\n<ul><li>Scientists report studies which seem to support the hypothesis that life may have begun in a shallow lake rather than otherwise - perhaps somewhat like a "warm little pond" originally proposed by Charles Darwin.</li>\n<li>A group of scientists from around the globe have charted paradigm shifting restorative pathways to mitigate the worst effects of climate change and biodiversity loss with a strong emphasis on environmental sustainability, human wellbeing and reducing social and economic inequality.</li>\n<li>Researchers have discovered a new phase of matter, named a "light-matter hybrid", which may reshape understanding of how light interacts with matter.</li>\n<li>A study of proteins in cerebrospinal fluid indicates there are five subtypes of Alzheimer\'s disease, suggesting it to be likely that subtype-specific treatments are required.</li>\n<li>A study finds seaweed farming could be set up as a resilient food solution within roughly a year in abrupt sunlight reduction scenarios such as after a nuclear war or a large volcano eruption.</li></ul></li>\n<li>10 January\n<ul><li>Chemists report studies finding that long-chain fatty acids were produced in ancient hydrothermal vents. Such fatty acids may have contributed to the formation of the first cell membranes that are fundamental to protocells and the origin of life.</li>\n<li>Scientists report the extinction of <i>Gigantopithecus blacki</i>, the largest primate to ever inhabit the Earth, that lived between 2 million and 350,000 years ago, was largely due to the inability of the ape to adapt to a diet better suited to a significantly changed environment.</li></ul></li>\n<li>11 January\n<ul><li>Biologists report the discovery of the oldest known skin, fossilized about 289 million years ago, and possibly the skin from an ancient reptile.</li>\n<li>Scientists report the discovery of <i>Tyrannosaurus mcraeensis</i>, an older species of <i>Tyrannosaurus</i> that lived 5-7 million years before <i>Tyrannosaurus rex</i>, and which may be fundamentally important to the evolution of the species.</li>\n<li>A study of the Caatinga region in Brazil finds that its semi-arid biome could lose over 90% of mammal species by 2060, even in a best-case scenario of climate change.</li>\n<li>A graphene-based implant on the surface of mouse brains, in combination with a two-photon microscope, is shown to capture high-resolution information on neural activity at depths of 250 micrometers.</li>\n<li>A review of genetic data from 21 studies with nearly one million participants finds more than 50 new genetic loci and 205 novel genes associated with depression, opening potential targets for drugs to treat depression.</li>\n<li>The Upano Valley sites are reported as the oldest Amazonian cities built over 2500 years ago, with a unique "garden urbanism" city design.</li>\n<li>A study presents results of a Riyadh-based trial of ei ...

# %%
# Extracting all values from events_dict with keys prepended
all_values = [f"{key} {value}" for key, values_list in events_dict.items() for value in values_list]
length = len(all_values)

# %%
# Create the dataframe to hold the text
df = pd.DataFrame(data={'text': all_values}, index=range(length))
df
# Out:
#                                                   text
# 0    2 January – The Japan Meteorological Agency (J...
# 1    3 January – The first functional semiconductor...
# 2    4 January – A review indicates digital rectal ...
# 3    5 January Scientists report that newborn galax...
# 4    5 January An analysis of sugar-sweetened bever...
# ..                                                 ...
# 105  15 May Solar energy is combined with synthetic...
# 106  16 May – A multimodal algorithm for improved s...
# 107  17 May – The world's smallest quantum light de...
# 108  20 May – The first measurements of an exoplane...
# 109                                            23 May
#
# [110 rows x 1 columns]

# %% [markdown]
# ## Custom Query Completion
#
# Get the embeddings for the text.

# %%
# Get OpenAI key
open_ai_key = pd.read_csv('D:\OneDrive\Security\keys.csv')
open.ai_key = open_ai_key[open_ai_key['Organization'] == 'Open_AI']['Key'][0]

client = OpenAI(api_key = open.ai_key)
client

# %%
def get_embedding(text_to_embed):
    """Get the embeddings for the text"""

    response = client.embeddings.create(
        model="text-embedding-ada-002",
        input=text_to_embed
    )

    return response

# %%
# Call the embeddings function
response = get_embedding(df['text'].tolist())
print(len(response.data))
# Out:
# 110

# %%
# Add the embeddings to the dataframe
df['embeddings'] = response.data
df
# Out:
#                                                   text  \
# 0    2 January – The Japan Meteorological Agency (J...
# 1    3 January – The first functional semiconductor...
# 2    4 January – A review indicates digital rectal ...
# 3    5 January Scientists report that newborn galax...
# 4    5 January An analysis of sugar-sweetened bever...
# ..                                                 ...
# 105  15 May Solar energy is combined with synthetic...
# 106  16 May – A multimodal algorithm for improved s...
# 107  17 May – The world's smallest quantum light de...
# 108  20 May – The first measurements of an exoplane...
# 109                                            23 May
#
#                                             embeddings
# 0    Embedding(embedding=[-0.0031084921211004257, -...
# 1    Embedding(embedding=[0.0021995967254042625, 0....
# 2    Embedding(embedding=[-0.023893123492598534, 0....
# 3    Embedding(embedding=[0.004181130789220333, 0.0...
# 4    Embedding(embedding=[0.005126591306179762, -0....
# ..                                                 ...
# 105  Embedding(embedding=[0.00849316269159317, -0.0...
# 106  Embedding(embedding=[-0.028770500794053078, -0...
# 107  Embedding(embedding=[-0.0015767208533361554, 0...
# 108  Embedding(embedding=[0.011667623184621334, 0.0...
# 109  Embedding(embedding=[-0.025530466809868813, 0....
#
# [110 rows x 2 columns]

# %%
# Check and make sure they are ok. You expect a length of 1536
temp = df['embeddings'].iloc[0]
len(temp.dict()['embedding'])
# Out:
# 1536

# %%
# Get the embeddings from the object using the embedding attribute
df['embeddings'] = df['embeddings'].apply(lambda x: x.embedding)
df
# Out:
#                                                   text  \
# 0    2 January – The Japan Meteorological Agency (J...
# 1    3 January – The first functional semiconductor...
# 2    4 January – A review indicates digital rectal ...
# 3    5 January Scientists report that newborn galax...
# 4    5 January An analysis of sugar-sweetened bever...
# ..                                                 ...
# 105  15 May Solar energy is combined with synthetic...
# 106  16 May – A multimodal algorithm for improved s...
# 107  17 May – The world's smallest quantum light de...
# 108  20 May – The first measurements of an exoplane...
# 109                                            23 May
#
#                                             embeddings
# 0    [-0.0031084921211004257, -0.0093239089474082, ...
# 1    [0.0021995967254042625, 0.012427395209670067, ...
# 2    [-0.023893123492598534, 0.014976626262068748, ...
# 3    [0.004181130789220333, 0.002602208172902465, -...
# 4    [0.005126591306179762, -0.003509768983349204, ...
# ..                                                 ...
# 105  [0.00849316269159317, -0.0034212269820272923, ...
# 106  [-0.028770500794053078, -0.003478819504380226,...
# 107  [-0.0015767208533361554, 0.022793881595134735,...
# 108  [0.011667623184621334, 0.009379075840115547, -...
# 109  [-0.025530466809868813, 0.006840140093117952, ...
#
# [110 rows x 2 columns]

# %%
# Check and make sure that worked. Should get 1536
len(df['embeddings'].iloc[0])
# Out:
# 1536

# %%
# Sample question
question = 'Where did life probably begin?'

# %%
def get_embeddings(question, df):
    
    # Get embedding for question from openai
    
    question_embeddings = client.embeddings.create(
        input = question, 
        model = "text-embedding-ada-002").data[0].embedding
    
    return question_embeddings

# %%
def calc_cosign_similarity(question_embeddings, df):

    # Calculate the cosign similarity between the question and the embeddings

    # Convert 'embeddings' column to numpy array
    embeddings_array = np.array(df['embeddings'].tolist())

    # Calculate cosine similarity
    cosine_sims = [cosine(question_embeddings, embedding) for embedding in embeddings_array]

    # Assign the cosine similarity to a new column in the DataFrame
    df['cosine_sims'] = cosine_sims

    # Sort the DataFrame by 'cosine_sims' column in ascending order
    df.sort_values('cosine_sims', inplace=True)

    # Reset the index of the DataFrame
    df.reset_index(inplace=True, drop=True)

    return df['text'].iloc[0]

# %%
# Example usage
question_embeddings = get_embeddings(question, df)
answer = calc_cosign_similarity(question_embeddings, df)
print(answer)
# Out:
# 9 January Scientists report studies which seem to support the hypothesis that life may have begun in a shallow lake rather than otherwise - perhaps somewhat like a "warm little pond" originally proposed by Charles Darwin.

# %% [markdown]
# ## Performance
# The purpose of this is to show the efficacy of RAG. I am going to pull out items from the pandas dataframe. Submit those to ChatGPT and have it return a question. Then I am going to use that question to see what the results are for the 3 different versions.
#
# - ChatGPT unassisted
# - Vector look up
# - ChatGPT assisted with RAG
#
# I could use input() and type the questions in but ... I hate typing and this is a far more interesting use of the technology. I could also, change the model that is generating the questions but ... that is for another day.

# %%
def chatgpt_answer(question):

    # https://platform.openai.com/docs/guides/text-generation/chat-completions-api

    # send a ChatCompletion request
    response = client.chat.completions.create(
        model = 'gpt-3.5-turbo',
        messages = [
            {'role': 'user', 
             'content': question}
        ],
        temperature = 0
    )
    
    return response

# %%
def question_answer_comparison(question, df):   
    
    # Using vector look up
    question_embeddings = get_embeddings(question, df)
    answer = calc_cosign_similarity(question_embeddings, df)
    print('\n', 'Using cosine similarity\n', answer)
    
    # GPT3 vanilla
    response = chatgpt_answer(question)
    print('\nChatGPT3.5 Unassisted\n', response.choices[0].message.content)
    
    # Using rag
    question_embeddings = get_embeddings(question, df)
    response = chatgpt_answer(rag_prompt(question, df))
    print('\nChatGPT3.5 with RAG\n', response.choices[0].message.content)

# %%
def rag_prompt(question, df):
    """Ceate a prompt that has the content from the pandas df"""
    
    # Get the embeddings
    question_embeddings = get_embeddings(question, df)
    
    # Get the text
    text = calc_cosign_similarity(question_embeddings, df)
    
    # Create the prompt
    message = f"You are an experienced scientific researcher. {question} Please consider this \
information when formulating your response. Pay particular attention to the date. \
I am looking for the most recent information. The dates in this text are all 2024. {text}. \
Restrict your answer to ONLY what is in this text."
    
    # Get rid of extra spaces
    message = message.strip(' ')
    
    return message

# %%
def summarize_prompt(df):
    
    """
    input df - pandas dataframe
    
    Does the following:
    Takes in the df. 
    Randomly selects a text item. 
    Creates a prompt from the text
    Submits it to ChatGPT and asks it to summarize and turn it into a question.
    
    output question - str
    """
    
    # Get a random piece of txt
    text = df.sample(1)['text'].iloc[0]
    
    # Create prompt
    message = f"You are an experienced scientific researcher. Formulate a Question based on this {text}. \
In the Question use at least some of these words 'who, when, where, how much, what quantity'."
    
    # Submit to ChatGPT
    response = chatgpt_answer(message)
    
    # Just the response
    question = response.choices[0].message.content
    
    # Just get the question
    question = question.split('\n\n')[-1]
    
    return question

# %% [markdown]
# ### Questions

# %%
# Lets ask some questions
questions_list = [summarize_prompt(df) for _ in range(5)]
questions_list
# Out:
# ['How much does the cancer detection rate differ between digital rectal examination and prostate-specific antigen testing in routine medical practice?',
#  'How many new moons were discovered in the Solar System on 23 February, and where are they located?',
#  'How much material was successfully recovered from the Bennu asteroid by NASA, and who was involved in the process of opening the container after three months of failed attempts?',
#  "How much have groundwater levels declined on average per year over the past four decades in 30% of the world's regional aquifers, and where have interventions such as policy changes successfully reversed depletion trends?",
#  "How much more effective and cost-efficient are Low Traffic Neighbourhoods compared to other active transport infrastructures in Outer London's Mini-Hollands in terms of health economic benefits?"]

# %%
for idx, question in enumerate(questions_list):
    print(idx + 1, '\n', question)
    print(question_answer_comparison(question, df), '\n#########\n')
# Out:
# 1
#  How much does the cancer detection rate differ between digital rectal examination and prostate-specific antigen testing in routine medical practice?
#
#  Using cosine similarity
#  4 January – A review indicates digital rectal examination is an outdated routine medical practice, with lower cancer detection rate compared to prostate-specific antigen testing.
#
# ChatGPT3.5 Unassisted
#  In routine medical practice, the cancer detection rate is generally higher with prostate-specific antigen (PSA) testing compared to digital rectal examination (DRE). PSA testing can detect prostate cancer at an earlier stage, often before it can be felt during a DRE. However, it is important to note that PSA testing can also lead to false positive results, which may result in unnecessary biopsies and treatment.
#
# Overall, studies have shown that PSA testing has a higher sensitivity for detecting prostate cancer compared to DRE. However, the optimal approach for prostate cancer screening remains a topic of debate, as both tests have limitations and potential risks. It is recommended that men discuss the benefits and risks of prostate cancer screening with their healthcare provider to make an informed decision about which tests to undergo.
#
# ChatGPT3.5 with RAG
#  According to a review from January 4, 2024, digital rectal examination is considered an outdated routine medical practice with a lower cancer detection rate compared to prostate-specific antigen testing.
# None
# #########
#
# 2
#  How many new moons were discovered in the Solar System on 23 February, and where are they located?
#
#  Using cosine similarity
#  23 February Three new moons of the Solar System are discovered, one around Uranus and two around Neptune, bringing their total known satellites to 28 and 16, respectively.
#
# ChatGPT3.5 Unassisted
#  On 23 February, 20 new moons were discovered in the Solar System. These moons are located around Saturn, with 17 of them orbiting the planet in the opposite direction of its rotation (retrograde orbit), and the other 3 in a prograde orbit.
#
# ChatGPT3.5 with RAG
#  On 23 February, three new moons were discovered in the Solar System. One was found around Uranus, bringing its total known satellites to 28. The other two were found around Neptune, increasing its total known satellites to 16.
# None
# #########
#
# 3
#  How much material was successfully recovered from the Bennu asteroid by NASA, and who was involved in the process of opening the container after three months of failed attempts?
#
#  Using cosine similarity
#  13 January – NASA fully opens the recovered container with samples from the Bennu asteroid, after three months of failed attempts.
#
# ChatGPT3.5 Unassisted
#  NASA successfully recovered approximately 400 grams of material from the Bennu asteroid. The team involved in the process of opening the container after three months of failed attempts included scientists and engineers from NASA's OSIRIS-REx mission, as well as personnel from Lockheed Martin, the company that built the spacecraft.
#
# ChatGPT3.5 with RAG
#  NASA successfully recovered material from the Bennu asteroid. The container with samples was fully opened on 13 January after three months of failed attempts.
# None
# #########
#
# 4
#  How much have groundwater levels declined on average per year over the past four decades in 30% of the world's regional aquifers, and where have interventions such as policy changes successfully reversed depletion trends?
#
#  Using cosine similarity
#  24 January A global analysis of groundwater levels reports rapid declines of over 0.5 meters per year are widespread and that declines have accelerated over the past four decades in 30% of the world's regional aquifers. The study also shows cases in which depletion trends have reversed following interventions such as policy changes.
#
# ChatGPT3.5 Unassisted
#  Groundwater levels have declined on average by 0.8 meters per year over the past four decades in 30% of the world's regional aquifers.
#
# Interventions such as policy changes have successfully reversed depletion trends in regions such as the High Plains aquifer in the United States, where the implementation of regulations and incentives for more sustainable groundwater use have led to stabilization or even slight increases in groundwater levels. Other successful interventions have been seen in regions like the Guadiana Basin in Spain, where the implementation of water pricing mechanisms and improved irrigation practices have helped to slow down groundwater depletion.
#
# ChatGPT3.5 with RAG
#  According to a global analysis conducted in 2024, groundwater levels have declined on average by over 0.5 meters per year over the past four decades in 30% of the world's regional aquifers. The study also highlights successful cases where interventions such as policy changes have reversed depletion trends.
# None
# #########
#
# 5
#  How much more effective and cost-efficient are Low Traffic Neighbourhoods compared to other active transport infrastructures in Outer London's Mini-Hollands in terms of health economic benefits?
#
#  Using cosine similarity
#  10 February – An analysis of Outer London's Mini-Hollands active transport infrastructures indicates Low Traffic Neighbourhoods are highly effective and cost-efficient measures in terms of health economic benefits.
#
# ChatGPT3.5 Unassisted
#  Low Traffic Neighbourhoods (LTNs) have been shown to be more effective and cost-efficient than other active transport infrastructures in Outer London's Mini-Hollands in terms of health economic benefits.
#
# One study found that LTNs can lead to a significant reduction in air pollution, which can have a positive impact on respiratory health and reduce the risk of cardiovascular diseases. This can result in cost savings for the healthcare system due to reduced hospital admissions and healthcare costs associated with air pollution-related illnesses.
#
# Additionally, LTNs have been shown to increase physical activity levels among residents by providing safer and more attractive walking and cycling routes. This can lead to improvements in overall health and well-being, as well as a reduction in the prevalence of chronic diseases such as obesity, diabetes, and heart disease.
#
# Furthermore, LTNs can help to reduce traffic congestion and improve road safety, leading to fewer traffic-related injuries and fatalities. This can result in cost savings for the healthcare system and other sectors, as well as increased productivity and quality of life for residents.
#
# Overall, LTNs offer a cost-effective and sustainable solution for promoting active transport and improving public health in Outer London's Mini-Hollands.
#
# ChatGPT3.5 with RAG
#  Based on the information provided in the text from 10 February 2024, Low Traffic Neighbourhoods are found to be highly effective and cost-efficient compared to other active transport infrastructures in Outer London's Mini-Hollands in terms of health economic benefits.
# None
# #########

# %% [markdown]
# ## Conclusions
# ChatGPT unassisted is amazingly good at lying. When it does not know the answer, it simply dreams something up. Since, ChatGPT is  so good at lying and it is trained on a large corpus, some of its "lies" may actually be truths. Just because it happened sometime on or before January 2022 does not mean it is not true today. It still could be true and part of a valid response.
#
# When I asked ChatGPT with RAG to restrict its answers to the input text it did not lie anymore and ws very accurate. I ran this code several times and on average ChatGPT 3.5 Unassisted got ~ 30% wrong. That is almost certainly a problem for most Chatbot applications. ChatGPT 3.5 With RAG was always correct but ... could not answer the question completely sometimes because the question posed by ChatGPT 3.5 Unassisted wanted information that was not in the RAG prompt. This was not common but did happen.
#
# When giving the LLM context, I did not return more than one result with this implementation. It is common to return the top several results to give the Large Language Model (LLM) more to work with. Since the sample size was so small and the individual pieces of information on the page were not expected to be closesly related, this is fine. However, depending on the application this may not be and would probably require some more prompt engineering to make sure that the application performed consistently well.
